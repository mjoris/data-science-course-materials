# %% [markdown]
# # Programmeren in Python 3: een inleiding
# ### K. Verbeeck, T. Vermeulen, J. Maervoet
# Data Science (Theory) -- OGI02i

# %% [markdown]
# ## Deel 1: wat is Python en welke tools zijn er voorhanden?

# %% [markdown]
# ### Python
# * programmeertaal, °1991 door Guido Van Rossum
# * Filosofie:leesbare en compacte code
#     * structuur door indentatie (dus niet door {})
#     * dynamisch getypeerd
#
# * multi-paradigm: functioneel, OO, proceduraal
# * referentie-implementatie: CPython
#    * open-source command-line **interpreter**
#    * compilatie van .py programma's naar bytecode
#    * vervolgens uitgevoerd door virtuele machine
#
# <div class="alert alert-block alert-danger">
# <b>Opgelet:</b> wij gebruiken Python 3 (niet compatibel met 2.*.*)
# </div>

# %% [markdown]
# ### IPython
#  * Verbeterde interactieve Python shell
#     * tab completion, command history, introspection (bv. _docstring_)
#  * Kan ingebed worden in en communiceren met andere programma's
#  * Kernel: verschillende clients kunnen instructies doorsturen voor evaluatie naar hetzelfde proces
#
# ![ipython.png](attachment:ipython.png)

# %% [markdown]
# ### Jupyter Notebook
# * Een interactieve webapplicatie om _notebook_ documenten (.ipynb __[formaat](https://nbformat.readthedocs.io/en/latest/format_description.html#)__) te creëren en te delen
# * Rijke documenten met uitvoerbare (Python-)code, begeleidende tekst, figuren, ...
# * Export naar tal van formaten met nbconvert
#
# ![jupy1.png](attachment:jupy1.png)

# %% [markdown]
# ### Een Jupyter _notebook_ editeren
# * 3 soorten cellen
#    * Markdown-cellen (__[syntax](https://daringfireball.net/projects/markdown/syntax)__)
#    * Code-cellen
#       * Rechtstreekse interactie met IPython kernel
#       * Kunnen een output hebben
#    * Cellen met rauwe nbconvert data
#
# ![jupy2.png](attachment:jupy2.png)

# %% [markdown]
# ### Makkelijk starten met Anaconda
# * __Anaconda:__ een Python-distributie voor data science met package manager
# * Link: __[https://www.anaconda.com/distribution/](https://www.anaconda.com/distribution/)__
# * Bevat de interpreter en ook klassieke libraries (onder Environments)
# ![anaconda.png](attachment:anaconda.png)

# %% [markdown]
# ### Meer informatie
# - __[The Python Tutorial](https://docs.python.org/3/tutorial/)__
# - __[IPython overview/documentation](https://ipython.readthedocs.io/en/stable/overview.html)__
# - __[Jupyter notebook documentation](https://jupyter-notebook.readthedocs.io/en/stable/notebook.html)__

# %% [markdown]
# ## Deel 2: programmeren in Python

# %% [markdown]
# ### Variabelen en evaluatie van expressies

# %%
# dit is commentaar
10 / 3
# Out:
# 3.3333333333333335

# %%
berekening = 5 * 6 + 3
print(berekening)
print(10 // 3) # gehele deling
print(10 ** 3) # machtsverheffing
# Out:
# 33
# 3
# 1000

# %%
# 4 basisdatatypes: int float str bool

getal = input('Geef een getal: ')
print(float(getal) / 5) # type conversion; anders TypeError door operator /
# Out:
# Geef een getal: 3
# 0.6

# %% [markdown]
# ### Strings (1)

# %%
langetekst = ('Lorem ipsum '
              'omnis mundi creaturi')
print(langetekst)
woord = 'py' + 'thon' * 2
print(woord + '\n')
print("He didn't say " + '"hello"')
print(r'\n')
# Out:
# Lorem ipsum omnis mundi creaturi
# pythonthon
#
# He didn't say "hello"
# \n

# %%
#formatting
print('{1} and {0}'.format('spam', 'eggs'))
# Out:
# eggs and spam

# %%
# include line ends using tripe-quotes
print("""\
Usage: thingy [OPTIONS]
     -h                        Display this usage message
     -H hostname               Hostname to connect to
""")
# Out:
# Usage: thingy [OPTIONS]
#      -h                        Display this usage message
#      -H hostname               Hostname to connect to

# %% [markdown]
# ### Strings (2)

# %%
woord = 'python'
print(len(woord)) # lengte van een string

# indexing and slicing
print('[1]: ' + woord[1])
print('[2:4]: ' + woord[2:4])
print('[-1]: ' + woord[-1])
print('[4:]: ' + woord[4:])
print('[:4]: ' + woord[:4])
# Out:
# 6
# [1]: y
# [2:4]: th
# [-1]: n
# [4:]: on
# [:4]: pyth

# %%
woord[0] = 'k'  # strings zijn onveranderlijk ...
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ffa2d4d2d48e> in <module>
# ----> 1 woord[0] = 'k'  # strings zijn onveranderlijk ...
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### Lists

# %%
squares = [1, 4, 9, 16, 25]

# indexing and slicing
print(squares[0])
print(squares[-3:])

squares.append(36)
squares += [100, 121]
squares[6:8] = [49]
print(squares)
mycopy = squares[:] # shallow copy
print(len(squares))
# Out:
# 1
# [9, 16, 25]
# [1, 4, 9, 16, 25, 36, 49]
# 7

# %% [markdown]
# ### Control flow (1)

# %%
x = 5
if x < 0:
    print('negatief')
elif x == 0:
    print('nul')
else:
    print('positief')
print(x)
# Out:
# positief
# 5

# %%
lijst = ['a', 'bb', 'ccc']
for woord in lijst:
    print(woord, len(woord))
# Out:
# a 1
# bb 2
# ccc 3

# %% [markdown]
# ### Control flow (2)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(range(0, 10, 3)) # hmmm... eigenlijk is dit een object
print(list(range(0, 10, 3)))
# Out:
# range(0, 10, 3)
# [0, 3, 6, 9]

# %%
# na : is een statement vereist
# gebruik pass als je geen actie vereist (pass doet niets)
for i in range(5):
    pass

# %% [markdown]
# ### Functies

# %%
def ask_ok(prompt, retries=4, reminder='Please try again!'): # default args
    """Asks the user for confirmation""" # dit is de docstring
    while True:
        ok = input(prompt)
        if ok in ('y', 'ye', 'yes'):
            return True
        if ok in ('n', 'no', 'nop', 'nope'):
            return False
        retries = retries - 1
        if retries < 0:
            raise ValueError('invalid user response')
        print(reminder)

ask_ok('OK to overwrite the file?', 2)
# Out:
# OK to overwrite the file?maybe
# Please try again!
# OK to overwrite the file?y
# True

# %%
ask_ok("is 't okee?", retries=0) # keyword arguments (steeds na postional args)
# Out:
# is 't okee?y
# True

# %% [markdown]
# ### Datastructures: lists (continued)

# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']
print(fruits.count('apple'))
fruits.sort()
fruits.reverse()
print(fruits)
del fruits[1:2]

stack = [3, 4, 5]
stack.pop()
print(stack)
# Out:
# 2
# ['pear', 'orange', 'kiwi', 'banana', 'banana', 'apple', 'apple']
# [3, 4]

# %%
# list comprehension
squares = [x**2 for x in range(10)]
print(squares)
vec = [-4, -2, 0, 2, 4]
print([x for x in vec if x >= 0])
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 2, 4]

# %% [markdown]
# ### Datastructures: tuples

# %%
resultaat = 25, 'Gent' # typisch voor heterogene data
print(resultaat[1]);
empty = ()
singleton = 'hello', 
v = ([1, 2, 3], [3, 2, 1])  # tuples zijn onveranderlijk, hun elementen eventueel wel ...
print(len(singleton), len(v))
# Out:
# Gent
# 1 2

# %%
# de iterator van enumerate geeft tuples terug
for i, v in enumerate(['tic', 'tac', 'toe']):
    print(i, v)
# Out:
# 0 tic
# 1 tac
# 2 toe

# %% [markdown]
# ### Datastructures: sets (verzamelingen)

# %%
verzameling1 = {'A', 'B', 'C', 'D'}
verzameling2 = set('DAXYDA') # omzetten van lists, strings, ... naar een set
print(verzameling2)
print('A' in verzameling1) # snel opzoeken
print(verzameling1 | verzameling2) # unie
print(verzameling1 & verzameling2) # doorsnede
# Out:
# {'D', 'A', 'X', 'Y'}
# True
# {'C', 'X', 'A', 'Y', 'B', 'D'}
# {'D', 'A'}

# %%
# set comprehension
a = {x for x in 'abracadabra' if x not in 'abc'}
print(a)
# Out:
# {'r', 'd'}

# %% [markdown]
# ### Datastructures: dictionaries

# %%
tel = {'jack': 4098, 'sape': 4139}
tel['guido'] = 4127

if 'jack' in tel: # snel opzoeken
    print(tel['jack'])
# Out:
# 4098

# %%
tel2 = dict(sape=4139, guido=4127, jack=4098) # je kan ook een lijst van koppels gebruiken
del tel2['sape']
print(tel2)
for k, v in tel2.items():
    print(k, v)
# Out:
# {'guido': 4127, 'jack': 4098}
# guido 4127
# jack 4098

# %% [markdown]
# ### \*args en \*\*kwargs
#
# * __\*args__ verwijst naar een lijst van (onbenoemde) argumenten van een functie
# * __\*\*kwargs__ verwijst naar een dictionary van keyword-argumenten van een functie
# * kunnen als argument gebruikt worden van een functie

# %%
def greetMe(name, **kwargs):  
    salutation = kwargs['sal'] if ('sal' in kwargs) else "Hallo" # omg it's a ternary operator
    print(salutation + ' ' + name)
  
greetMe('Joris', sal='Hoi')
# Out:
# Hoi Joris

# %% [markdown]
# * in principe kan om het even welke variabelenaam gebruikt worden, als de sterren er maar staan
# * \*args en \*\*kwargs worden steevast gebruikt in de documentatie van libraries

# %% [markdown]
# ### Anonieme functies met _lambda_

# %%
add = lambda x, y: x + y
add(5, 6)
# Out:
# 11

# %%
a = [(1, 2), (4, 1), (9, 10), (13, -3)]
a.sort(key=lambda x: x[1])
print(a)
# Out:
# [(13, -3), (4, 1), (1, 2), (9, 10)]

# %%
items = [1, 2, 3, 4, 5]
squared = list(map(lambda x: x**2, items)) # map returns an iterator
print(squared)
odd = list(filter(lambda x: x % 2 == 1, squared)) # filter returns an iterator
print(odd)
# Out:
# [1, 4, 9, 16, 25]
# [1, 9, 25]

# %% [markdown]
# ### Is dit alles?
#  * nee zeker niet, dit waren maar stukjes uit de __[Python 3 tutorial](https://docs.python.org/3/tutorial/)__
#  * zeer toegankelijke cursus: __[geo-python](https://geo-python.github.io/site/index.html)__
#  * de officiële documentatie van __The Python Standard Library__ vind je __[hier](https://docs.python.org/3/library/)__
#  * leuke tips als je al een beetje Python kan: __[Intermediate Python Tips](https://book.pythontips.com/en/latest/index.html)__

# %% [markdown]
# ## Deel 3: libraries: een voorproefje ...

# %% [markdown]
# ### Import
# * Een module ~ een bestand
# * Een package ~ een verzameling modules in een mappenhiërarchie
# * In een module zitten items (functies, klassen, ...) aan te roepen met .

# %%
import math # importeren van de math module

print('pi is', math.pi)
# Out:
# pi is 3.141592653589793

# %%
import math as wiskunde

print('pi is', wiskunde.pi)
# Out:
# pi is 3.141592653589793

# %%
from math import cos, pi # from laat toe items, modules te importeren (en jokerteken *)

print('cos(pi) is', cos(pi))
# Out:
# cos(pi) is -1.0

# %% [markdown]
# ### De NumPy library
# * Performante ondersteuning voor grote multi-dimensionele arrays (matrices) en bijhorende operatoren uit de numerieke wiskunde
# * Centrale datastructuur: _ndarray_
# * __[Quickstart](https://docs.scipy.org/doc/numpy/user/quickstart.html)__
# * Hier komen we volgende week op terug

# %%
import numpy as np

a = np.array([1, 2, 3])
print(a[0], type(a))
print(a)

print(np.arange(0, 3, 0.25)) # standard python kan geen ranges met kommagetallen genereren
# Out:
# 1 <class 'numpy.ndarray'>
# [1 2 3]
# [0.   0.25 0.5  0.75 1.   1.25 1.5  1.75 2.   2.25 2.5  2.75]

# %%
d = np.eye(3) 
print(d)
e = np.full((3,3), 7)
print(e)
print(d*e)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# [[7 7 7]
#  [7 7 7]
#  [7 7 7]]
# [[7. 0. 0.]
#  [0. 7. 0.]
#  [0. 0. 7.]]

# %% [markdown]
# ## Matplotlib
#
# * Kwaliteitsvolle 2D-plot-bibliotheek
# * Startpunt: de __[matplotlib tutorials](https://matplotlib.org/tutorials/index.html)__

# %%
import matplotlib.pyplot as plt

# Some nice x and y coordinates
x = [0, 1, 2, 3, 2, 1, 0]
y = [0, 0, 3, 2, 2, -2, 0]

# Plot the points using matplotlib
plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot the points using matplotlib
plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot the points using matplotlib with labels, a title, ticks, a grid and a legend
plt.plot(x, y, 'r.')
plt.xlabel('tijd (minuten)')
plt.ylabel('hersenactiviteit (pulsen per seconde)')
plt.title('Aandachtscurve')
plt.xticks(range(0,10))
plt.grid(color='b', linestyle='--', linewidth=.5)
plt.legend(['Meting op vr 14/2'])
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
